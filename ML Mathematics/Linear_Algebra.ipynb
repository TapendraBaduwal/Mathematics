# %% [markdown]
# #**Linear Algebra**:
# - To understand how each algorithm works, you need to know linear algebra. Concepts in linear algebra help implement machine learning algorithms from scratch.
#
# - Linear algebra basically deals with vectors and matrices (different shapes of arrays) and operations on these arrays. In NumPy, vectors are basically a 1-dimensional array of numbers but geometrically, they have both magnitude and direction.

# %% [markdown]
# #**Vectors Operations**
# - Vector is a list of numbers or a 1-D data structure.This helped us understand how we could encode information from our datasets as inputs to pass to our ML models.
#
# - Within these models, once that input is received, it’s important to understand that vectors are objects which have the unusual distinction of having both a magnitude and a direction:
#
#
# - Computer Science people can interpret Vectors as a list of numbers that represent something.
# - Physicists consider Vectors to be a scalar with a direction and it is independent of the plane.
# - Mathematicians take Vectors to be a combination of both and try to generalize it for everyone.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Plotting a vector
sns.set() #default theme to creat cell
#(0,0) is base coordinate of the vector and (4,5) is head coordinate of the vector
#quiver is the function to plot vector
plt.quiver(0,0,4,5, scale_units='xy', angles='xy', scale=1,color='g')
plt.xlim(-8,8)
plt.ylim(-8,8)
plt.show()

# %% [markdown]
# ###**Addition of two Vectors**
# - Vectors in the same direction can be simply added to obtain the resultant vector.
#
# - A displacement(resultant) vector is the vector directing towards final position whose length is the shortest distance between the initial and the final point.
#
# - Vectors are added geometrically and not algebraically.

# %%
vector_1 = np.asarray([0,0,2,3])

vector_2 = np.asarray([0,0,3,-2])

sum = vector_1 + vector_2
print(sum)
# Out:
# [0 0 5 1]

# %%
plt.quiver(0,0,2,3, scale_units='xy', angles='xy', scale=1, color='b')
plt.quiver(0,0,3,-2, scale_units='xy', angles='xy', scale=1, color='y')
plt.quiver(0,0,5,1, scale_units='xy', angles='xy', scale=1, color='r')
plt.xlim(-8,8)
plt.ylim(-8,8)
plt.show()

# %% [markdown]
# ###**Subtraction of two vectors**
# - To better understand this, let us consider an example of a car travelling 10 miles North and 10 miles South. Here, the total distance travelled is 20 miles but the displacement is zero.

# %%
vector_1 = np.asarray([0,0,2,3])

vector_2 = np.asarray([0,0,3,-2])

difference = vector_1 - vector_2
print(difference)
# Out:
# [ 0  0 -1  5]

# %%
plt.quiver(0,0,2,3, scale_units='xy', angles='xy', scale=1, color='b')
plt.quiver(0,0,3,-2, scale_units='xy', angles='xy', scale=1, color='y')
plt.quiver(0,0,-1,5, scale_units='xy', angles='xy', scale=1, color='r')
plt.xlim(-8,8)
plt.ylim(-8,8)
plt.show()

# %% [markdown]
# ###**Multiplying a vector by a scalar**

# %%
vector_1 = np.asarray([0,0,2,3])

vector_2 = 2*vector_1

print(vector_2)
# Out:
# [0 0 4 6]

# %%
plt.quiver(0,0,2,3, scale_units='xy', angles='xy', scale=1, color='b')
plt.quiver(0,0,4,6, scale_units='xy', angles='xy', scale=1, color='y')
plt.xlim(-8,8)
plt.ylim(-8,8)
plt.show()

# %%
vector_1 = np.asarray([0,0,2,3])

vector_2 = -0.5*vector_1

print(vector_2)
# Out:
# [-0.  -0.  -1.  -1.5]

# %%
plt.quiver(0,0,2,3, scale_units='xy', angles='xy', scale=1, color='b')
plt.quiver(0,0,-1,-1.5, scale_units='xy', angles='xy', scale=1, color='y')
plt.xlim(-8,8)
plt.ylim(-8,8)
plt.show()

# %% [markdown]
# ###**Dot Product of two Vectors**
#
# - The dot product, of two vectors, is the sum of the products of corresponding components.
# -  The resultant of the dot product of vectors is a scalar quantity.
# - $\vec{a}.\vec{b}$ = $a_1b_1 +a_2b_2 +a_3b_3+...+a_nb_n$
#
#
# - The weighted sum can be re-written as a dot product, which is more convenient notation, and can be computed more efficiently. Let the vector x=[x1,…,xn] contain the inputs, and the vector w=[w1,…,wn] contain the corresponding weights. By the definition of the dot product:
#
# - $WeightedSum= w_1x_1 +w_2x_2 +...+w_nx_n +bias$
#
# - After calculating Weighted Sum we pass this values to Activtion function and this activation function generate particular value for the given node ,this value act as input for next node as so on.

# %%
a = np.array([2, 3])
b = np.array([4, 4])
a_dot_b = np.dot(a, b)
print(a_dot_b)
# Out:
# 20

# %%
c = np.array([5, 3, 7])
d = np.array([4, 2, 3])
c_dot_d = np.dot(c, d)
print(c_dot_d)
# Out:
# 47

# %% [markdown]
# ###**Cross Product of two Vectors**
# - A = ai + bj + ck
#
# - B = xi + yj + zk
#
# - A*B = $\begin{vmatrix}
# i & j & k \\
# a & b & c \\
# x & y & z \\
# \end{vmatrix}$
#
# - We can also derive the formula for the cross product of two vectors using the determinant of the matrix as given below.
#
# -  $\vec{a}*\vec{b}$ = $i(bz – cy) - j(az – cx) + k(ay – bx)$

# %%
a = np.array([2, 3])
b = np.array([4, 4])
a_cross_b = np.cross(a, b)
print(a_cross_b)
# Out:
# -4

# %%
c = np.array([5, 10, 20])
d = np.array([18, 32, 50])
c_cross_d = np.cross(c, d)
print(c_cross_d)
# Out:
# [-140  110  -20]

# %% [markdown]
# ####**MAGNITUDE AND DIRECTION OF A VECTOR**
#
# - The magnitude of a vector A is the length of the vector and is denoted by |A|.
#
#
# - **Magnitude of a Vector |A|** =$\sqrt{(x_2-x_1)^2+(y_2-y_1)^2}$
#
#
# - Note:The formula to determine the magnitude of a vector in three dimensional space include Z axis also.
#
#
#
# - **Direction of a Vector(θ)** =$tan^-1( \frac{y_2-y_1}{x_2-x_1})$
#
#
# - where,
#
# - $x_{1}$ and $y_{1}$ are tail or base coordinate points of vector.
#
# - $x_{2}$ and $y_{2}$ are head coordinate  points of vector.

# %% [markdown]
# ##**Cosine Similarity**
# - Mathematically cosine similarity  is the dot product of the vectors divided by their magnitude.
# -  **Cosine Similarity of Vector cos($\theta$)** =$\frac{A.B}{|A||B|}$
# - Where, $\theta$ = Angle  between the vectors A and B.
# - A.B = Dot product between vectors A and B.
# - |A| and |B| are the magnitude of two vectors.
# - The angle between the vectors is calculated as: $\theta$=$cos^-1(\frac{A.B}{|A||B|})$
#
# - The similarity can take values between -1 and +1. The smaller the angle between the two vectors, the more similar they are to each other. For example:
#
# - When two vectors have the same orientation, the angle between them is 0, and the cosine similarity is 1 i.e The value of cos0 is 1.Value 1 indicates a high similarity between the vectors
#
# - Perpendicular vectors have a 90-degree angle between them and a cosine similarity of 0 i.e The value of cos90 is 0.Value 0 indicates independent (or orthogonal) vectors.
#
# - Opposite vectors have an angle of 180 degrees between them and a cosine similarity of -1 i.e The value of cos180 is equal to -1.Value −1 value will indicate strongly opposite vectors i.e. no similarity.
#
#
# - Also, Cosine Distance = 1 — Cosine Similarity
#
# - Applications of cosine similarity:
# - The metric is used in processes of data mining, information retrieval, and text matching.
# - Used in a recommendation engine to recommend similar products/movies/shows/books.
# - The cosine-similarity based locality-sensitive hashing technique increases the speed for matching DNA sequence data.

# %% [markdown]
# ##**Matrix Arithmetic**

# %% [markdown]
# **Matrix Addition:**
# - Two matrices with the same dimensions can be added together to create a new third matrix.

# %%
# add matrices
import numpy as np
A = np.array([[1, 2, 3], [4, 5, 6]])
print(A)
B = np.array([[1, 2, 3], [4, 5, 6]])
print(B)
C = A + B
print(C)
print(np.add(A,B))
# Out:
# [[1 2 3]
#  [4 5 6]]
# [[1 2 3]
#  [4 5 6]]
# [[ 2  4  6]
#  [ 8 10 12]]
# [[ 2  4  6]
#  [ 8 10 12]]

# %% [markdown]
# **Matrix Subtraction**
#
# - Similarly, one matrix can be subtracted from another matrix with the same dimensions.

# %%
# subtract matrices
import numpy as np
A = np.array([[1, 2, 3], [4, 5, 6]])
print(A)
B = np.array([[0.5, 0.5, 0.5], [0.5, 0.5, 0.5]])
print(B)
C = A - B
print(C)
print(np.subtract(A,B))
# Out:
# [[1 2 3]
#  [4 5 6]]
# [[0.5 0.5 0.5]
#  [0.5 0.5 0.5]]
# [[0.5 1.5 2.5]
#  [3.5 4.5 5.5]]
# [[0.5 1.5 2.5]
#  [3.5 4.5 5.5]]

# %% [markdown]
# **Matrix-Matrix Multiplication(dot products)**
#
# - The concept of a dot product (matrix multiplication) of vectors or matrix tells us more about the similarity of two vectors or matrix. And it has applications in correlation/covariance calculation, linear regression, logistic regression, PCA, convolutions, PageRank and numerous other algorithms.
#
# - To perform multiplication of two matrices, we should make sure that the number of columns in the 1st matrix is equal to the rows in the 2nd matrix. Therefore, the resulting matrix product will have a number of rows of the 1st matrix and a number of columns of the 2nd matrix.
#
# - Multiply each row of the first matrix with each column of the second matrix and add all to get the first element.

# %%
from numpy import array
A = array([[1, 2], [3, 4], [5, 6]])
print(A)
B = array([[1, 2], [3, 4]])
print(B)
C = A.dot(B)
print(C)
# Out:
# [[1 2]
#  [3 4]
#  [5 6]]
# [[1 2]
#  [3 4]]
# [[ 7 10]
#  [15 22]
#  [23 34]]

# %%
import numpy as np
a = np.array([[1, 0],
              [0, 1]])
b = np.array([[4, 1],
              [2, 2]])
np.matmul(a, b)
# Out:
# array([[4, 1],
#        [2, 2]])

# %% [markdown]
# **Transpose of a Matrix($A^T$) :**
# - The transpose of a Matrix is the interchanged rows and columns that result in a new Matrix.
# - Transpose can be used to flip the dimensions of a Matrix or Pixel which represent information.
#
# - i.e  Since we have a image matrix, aba teyo image lai ulto rakhera photo lida tesko pixal haru flip or reverse hunxan, testo case ma transpose of a Matrix  ko use garna milxa.

# %%
a = np.array([[1, 2], [3, 4]])
print(a)
a.transpose()
# Out:
# [[1 2]
#  [3 4]]
# array([[1, 3],
#        [2, 4]])

# %% [markdown]
# **Determinant of a Matrix($|A|$) :**
# - The Determinant of a Matrix is the value of a Matrix, specifically, it tells you the Scalar of a Matrix.
# - The determinant gives you the product of the Eigenvalues in the Matrix.
# - i.e Scaler value auxa jasle auta matrix ko unique identity represent garxa like weight represent garxa.

# %%
a = np.array([[1, 2], [3, 4]])
print(a)
np.linalg.det(a)
# Out:
# [[1 2]
#  [3 4]]
# -2.0000000000000004

# %% [markdown]
# **Inverse of a Matrix($A^-1$):**
#
# - $A^-1$= adj(A)/det(A)
#
# - To find the adjoint of a matrix, first find the cofactor matrix of the given matrix. Then find the transpose of the cofactor matrix.
#
# - Inverse matrices are frequently used to encrypt or decrypt message ,image pixel.

# %%
from numpy.linalg import inv
a = np.array([[1, 2], [3, 4]])
print(a)
ainv = inv(a)
print(ainv)
# Out:
# [[1 2]
#  [3 4]]
# [[-2.   1. ]
#  [ 1.5 -0.5]]

# %% [markdown]
# **Properties of Matrix Multiplication**
#
# **(a)Commutative Property:**
#
# - The matrix multiplication is not commutative.
#
# - Assume that, if A and B are the two 2×2 matrices,
#
# - AB ≠ BA
#
# - In matrix multiplication, the order matters a lot.
#
#
# **(b)Associative Property**
#
# - If A, B and C are the three matrices, the associative property of matrix multiplication states that,
#
# - (AB) C = A(BC)
#
#
# **(c)Distributive Property**
# - If A, B and C are the three matrices, the distributive property of matrix multiplication states that,
#
# - (B+C)A = BA +CA
# - A(B+C) = AB + AC

# %% [markdown]
# **Tensors**
#
# - A Tensor is a N-dimensional Matrix:
#
# - A Scalar is a 0-dimensional tensor
# - A Vector is a 1-dimensional tensor
# - A Matrix is a 2-dimensional tensor
# - A Tensor is a generalization of Vectors and Matrices to higher dimensions.
#
# - Technically, all of the above are tensors, but when we speak of tensors, we generally speak of matrices with a dimension larger than 2.

# %% [markdown]
# ##**EigenValues and Eigen Vectors:**
#
# - Eigenvalues are associated with eigenvectors in Linear algebra. Both terms are used in the analysis of linear transformations.
# - So what’s an EigenValue? It’s the list of factors by which the vector transformations do not affect the direction of the EigenVector.
#
# - Putting it to a definition, EigenVectors are those vectors that do not change its direction even if transformation is applied to them. The list of values by which the transformations are applied on the EigenVector and make sure that the direction does not change is the EigenValues.
#
# - $AV = λV$ , for V does not equal to 0.
# - The number or scalar value “λ” is an eigenvalue of Matrix A and V is an eigenvector of A corresponding to eigenvalue λ.
#
# - Finally, concepts like EigenValues and eigenvectors allow us to reduce the number of features or dimensions of the data while keeping the essence of all of them using something called principal component analysis.
#
# **EigenValues:**
# - Eigenvalues are the special set of scalars associated with the system of linear equations.
# - It is mostly used in matrix equations.
# - $det(A.A^T- λI)=0$
#
#
# **Eigen Vectors:**
#
# - Eigenvectors are the vectors (non-zero) that do not change the direction when any linear transformation is applied.It changes by only a scalar factor.
# - $(A.A^T-λI)V = 0$
#
# - $Feature Vector = (V_1, V_2)$

# %% [markdown]
# ##**Singular Value Decomposition (SVD):**
#
# - The Singular Value Decomposition (SVD) of a matrix is a factorization of that matrix into three matrices. It has some interesting algebraic properties and conveys important geometrical and theoretical insights about linear transformations.
#
# - Singular Value Decomposition (SVD) is a common dimensionality reduction technique in data science used in Image Compression ,old damage Image Recovery,Eigenfaces ,Spectral Clustering ,Background Removal from Videos.
#
# - Matrix A SVD = $USV^T$
#
# - Where, U is an (m x m) orthogonal matrix of eigenvectors.
# - S: is  mxn diagonal matrix of the singular values which are the square roots of the eigenvalues.The singular values are defined as the square root of the obtained Eigen values.
#
# - $V^T$: is transpose of a nxn matrix containing the orthonormal eigenvectors.
#
#
# - An orthogonal matrix is a square matrix with real numbers that multiplied by its transpose is equal to the Identity matrix.
# - Condition of orthogonal matrix $U.U^T = V.V^T = I$ , (i.e. U and V are orthogonal)
#
# - Next step is to calculate the eigenvalues(λ) and eigenvectors(V).
#
# $$det(A.A^T- λI)=0$$
#
# - From above equation we get λ .
#
# - - For each eigenvalue($λ$), a corresponding eigen-vector(V), can be found by solving:
# $$(A.A^T-λI)V = 0$$
#
# - - Next we form a feature vector which is a matrix of eigenvectors.
# $$Feature Vector = (V_1, V_2)$$
#        .

# %% [markdown]
# #**Gradient Descent**
#
# - Gradient Descent is an algorithm to minimize the **cost function(error function)**  by **optimizing(Best fitting) its parameters.**
#
# - The cost function($J$) is  the **sum of squared error multiplied by $\frac{1}{2}$ to make the derivation easier.**
#
# - To find the **best-fit regression line**, the model aims to predict **$y$** value such that the error difference between Actual value and predicted value is minimum.
# - So, it is very important to update the value of  $β_0$, $β_1$,$β_2$,....,$β_n$ , to reach the best value that **minimize the error** between Actual output value and  predicted output value.
#
# - It is done by a random selection of values of coefficient and then iteratively update the values to reach the minimum cost function.
#
# - Gradient Descent  is mostly used in Linear regression, logistical regression,Principal component analysis (PCA),neural network etc and other various  machine learning and deep learning.
#
#
# ####**Lets  we have initial values of Paremeters $β_0$, $β_1$,$β_2$,....,$β_n$ (which is Randomly Initialization)**
#
#
# $$\boldsymbol{\beta} =\begin{bmatrix}
# \beta_0 \\
# \beta_1 \\
# \beta_2 \\
# \vdots \\
# \beta_n
# \end{bmatrix}$$
#
# ####**Since we have a cost function as below:**
#
# Lets we have actual output value of y is  $y_i = \beta_0+\beta_1x_{i1} +\beta_2x_{i2} +....+ \beta_nx_{in} + \epsilon_i$
#
# Also we have predicted  output  value of y is  $\hat{y_i} = \beta_0+\beta_1x_{i1} +\beta_2x_{i2} +....+ \beta_nx_{in}$
#
# where $\epsilon_i$ is error and $x_i$ is positional independent input variables.
#
#
#
# Then the Cost Function is written as:
#
#
# \begin{align}
# J(\beta_0, \beta_1, \beta_2,..., \beta_n) &= \frac{1}{2}\sum_{i=1}^{n}({y_{i}}-\hat{y_{i}})^2 \\
# &= \frac{1}{2}\sum_{i=1}^{n}(y_{i}-(\beta_0+\beta_1x_{i1} +\beta_2x_{i2} +....+ \beta_nx_{in}))^2
# \end{align}
#
# ###**Taking Partial derivative of the cost function with respect to  $\beta_0$ then we get:**
#
# $$\frac{\partial\ \text{J}}{\partial \beta_0}  = \frac{1}{2}\sum_{i=1}^{n}\frac{\partial }{\partial \beta_0}(y_{i}-\hat{y_{i}})^2$$
#
# Now apply chain and power rules:
# $$=\frac{1}{2}\ \sum_{i=1}^{n}\frac{\partial ({y_{i}}-\hat{y_{i}})^2}
# {\partial ({y_{i}}-\hat{y_{i}})} \times \frac{\partial ({y_{i}}-\hat{y_{i}})}{\partial \beta_0}$$
#
# $$=\sum_{i=1}^{n}({y_i} - \hat{y_i}) \times \frac{\partial (y_i-(\beta_0 + \beta_1x_{i1} + \beta_2x_{i2} +...+ \beta_nx_{in}))}{\partial \beta_0}$$
#
# $$=\sum_{i=1}^{n}({y_i} - \hat{y_i}) \times (-1)$$
#
# $$=-\sum_{i=1}^{n}({y_i} - \hat{y_i})$$
#
#
# Similarly ,Taking Partial derivative of the cost function with respect to  $\beta_1$,$\beta_2$,...,$\beta_n$ then we get:
#
# $$\frac{\partial\ \text{J}}{\partial \beta_1} =-\sum_{i=1}^{n}({y_i} - \hat{y_i})x_{i1}$$
#
# $$\frac{\partial\ \text{J}}{\partial \beta_2} =-\sum_{i=1}^{n}({y_i} - \hat{y_i})x_{i2}$$
# \begin{align}\dots \\\dots \\\end{align}
#
# $$\frac{\partial\ \text{J}}{\partial \beta_n} =-\sum_{i=1}^{n}({y_i} - \hat{y_i})x_{in}$$
#
# Finally we  can write in the matrix form as below:
# $$\frac{\boldsymbol{\partial J}}{\boldsymbol{\partial \beta}} = \begin{bmatrix}
# \frac{\partial J}{\partial \beta_0} \\
# \frac{\partial J}{\partial \beta_1}\\
# \frac{\partial J}{\partial \beta_2}\\
# \vdots \\
# \frac{\partial J}{\partial \beta_n}
# \end{bmatrix} $$
#
#
# ###**Lets update the value of parameters(optimizing its parameters to get Best fitting regression line) until the cost function converges to its minimum value:**
#
# Repeat the process until cost function converges to its minimum value:
# $$\beta_0 :=\beta_0 - \alpha\frac{\partial J}{\partial \beta_0}$$
#
# $$\beta_1 :=\beta_1-\alpha\frac{\partial J}{\partial \beta_1}$$
#
# $$\beta_2 :=\beta_2-\alpha\frac{\partial J}{\partial \beta_2}$$
#
# $$\vdots \\
# \beta_n :=\beta_n-\alpha\frac{\partial J}{\partial \beta_n}$$
#
# **Note:** The  slop may be +ve or -ve,the slop of line decides in which direction to moves.That help to decide whether we have to add or subtract  on old paremeters to get new paremeters.New gradient tells us the slope of our cost function at our current position and the direction we should move to update our parameters.
#
# ###**LEARNING RATE:**
# Here, $\alpha$ is learning rate which determine the size of the step that we take.
# This parameter determines how fast or slow we move towards the optimal weights while minimizing cost function at every step. High learning rate could cover more area per step but would risk overshooting the minima; low learning rate would take virtually forever to reach the minma.

# %% [markdown]
# #**Sigmoid Function(Logistic Function):**
#
# - Since we have predicted output  equation of linear regression as follows:
# $$\hat{y} = \beta_0 + \beta_1\ x_1+....+\beta_n\ x_n$$
#
# - Mathmatically Sigmoid Function can be express as follows:
# $$f(x) = \frac 1 {1+ e^{-\hat{y}}} $$
#
# - 	where, e is Euler's number.
#
#
# - After putting the value of $\hat{y}$ we get Sigmoid Function  as follows:
# $$f(x) = \frac 1 {1 + e^{-(\beta_0 + \beta_1\ x_1+....+\beta_n\ x_n)}}$$
#
# - If the value of $f(x)$ goes to $+ve$ infinity then the predicted value of $f(x)$ will become 1 and if it goes to $-ve$ infinity then the predicted value of $f(x)$ will become 0. And if the outcome of the sigmoid function is more than 0.5 then we classify that label as class 1 or positive class and if it is less than 0.5 then we can classify it to negative class or label as class 0.

# %% [markdown]
# ##**Mathematics Behind Principal Component Analysis(PCA)**
#
# - Lets we have two dimensions(features) dataset x and y
#
# - Since the dataset we took is 2-dimensional, this will result in a 2x2 Covariance matrix.The Covariance matrix of these two features as follows:
#
# \begin{align}
#         \ CovarianceMatrix(C)  = \begin{pmatrix}
#         \ cov(x,x) & \ cov(x,y) \\\\
#         \ cov(y,x) & \ cov(y,y)
#         \end{pmatrix}
#     \end{align}
#
# - Covariance matrix is a square matrix that measure the variations of datapoint from the mean parameter values.
#
# - Where, Covariance of each data point is calculated as follows;
#
#  \begin{align}
#         \ cov(x,y) = \sum_{i=1}^n \frac{(x_i -\bar{x}) (y_i -\bar{y})}
#         {(n-1)}
#     \end{align}
#
#
# - Since we have identity matrix(I) of the same dimension as C.
# \begin{align}
#         \ I = \begin{pmatrix}
#         \ 1 & \ 0 \\\\
#         \ 0 & \ 1
#         \end{pmatrix}
#     \end{align}
#
# - Next step is to calculate the eigenvalues(λ) and eigenvectors(V) for the covariance matrix.
#
# $$det(C- λI)=0$$
#
# - Where,C is CovarianceMatrix,$λ$ is an eigenvalue for a matrix C , I is the identity matrix of the same dimension as C and ‘det’ is the determinant of the matrix.
#
# - After solving above process we will get equation ,by solving this equation we will get different values of $λ$.
#
# - For each eigenvalue($λ$), a corresponding eigen-vector(V), can be found by solving:
# $$(C-λI)V = 0$$
# - After solving this equation we get;
# \begin{align}
#         \ V = \begin{pmatrix}
#         \ x_1 &  \\\\
#         \ y_1 &
#         \end{pmatrix}
#     \end{align}
#
# - If we have a dataset with **$n$ variables, then we have the corresponding $n$ eigenvalues and eigenvectors.**To reduce the dimensions, **we choose the first p(nearly 2 0r 3) eigenvalues and ignore the rest.**
# - Since the **first p(nearly 2 or 3) eigenvalues contain nearly 98% information of our dataset.**
#
# - Next we form a feature vector which is a matrix of eigenvectors.
# $$Feature Vector = (V_1, V_2)$$
#
# - Finally we form the principal components by taking the **transpose of the feature vector and multiply it with the transpose of scaled version of original dataset.**
# $$NewData(Principal Components)= FeatureVector^T . ScaledData^T$$
#
#
#
# - Since the **first PC(nearly 2 or 3)  contain nearly 98% information of our dataset.**So we can take first PC(nearly 2 or 3) as a new feature for our dataset.
#
#
#
# - **NOTE:** $PC_1$=$λ_1F_1$ +$λ_2F_2$+...+$λ_nF_n$  ,Simaraly use same formula for $PC_2$ ,Here values of  $λ_1$,$λ_2$,..,$λ_n$ different for $PC_1$,$PC_2$...$PC_n$.We take orginal feature from the client and develop internal system to convert it too PC values and gives output by model.
